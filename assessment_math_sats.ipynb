# %%
import pandas as pd

# %%
csv_file_path = 'assessment_da25.csv'
assessment_da25 = pd.read_csv(csv_file_path)

# %%
print(assessment_da25)
# Out:
#      Variant  Number of page views  GMV (in $)  Number of add to cart  \
# 0          A                     5        0.00                      0
# 1          A                     4        0.00                      4
# 2          A                     4        0.00                      2
# 3          A                     5        0.00                      0
# 4          A                     5        0.00                      3
# ...      ...                   ...         ...                    ...
# 1995       B                     3        0.00                      1
# 1996       B                     3        0.00                      1
# 1997       B                     3        0.00                      2
# 1998       B                     4       87.08                      2
# 1999       B                     7        0.00                      5
#
#       Clicks on media  Time on Page (sec)  user_id
# 0                   2                  74        0
# ...

# %%
print(assessment_da25.head())
# Out:
#   Variant  Number of page views  GMV (in $)  Number of add to cart  \
# 0       A                     5         0.0                      0
# 1       A                     4         0.0                      4
# 2       A                     4         0.0                      2
# 3       A                     5         0.0                      0
# 4       A                     5         0.0                      3
#
#    Clicks on media  Time on Page (sec)  user_id
# 0                2                  74        0
# 1                1                  21        1
# 2                0                   1        2
# 3                1                  26        3
# 4                3                  46        4

# %%
print(assessment_da25.describe())
# Out:
#        Number of page views   GMV (in $)  Number of add to cart  \
# count           2000.000000  2000.000000            2000.000000
# mean               5.151000     8.489760               2.176500
# std                2.333864    27.861282               1.518387
# min                0.000000     0.000000               0.000000
# 25%                3.000000     0.000000               1.000000
# 50%                5.000000     0.000000               2.000000
# 75%                7.000000     0.000000               3.000000
# max               15.000000   152.610000              10.000000
#
#        Clicks on media  Time on Page (sec)      user_id
# count      2000.000000         2000.000000  2000.000000
# mean          1.409500           20.295000   999.500000
# std           1.208528           19.964676   577.494589
# min           0.000000            1.000000     0.000000
# 25%           1.000000            6.000000   499.750000
# ...

# %%
print(assessment_da25.isnull().sum())
# Out:
# Variant                  0
# Number of page views     0
# GMV (in $)               0
# Number of add to cart    0
# Clicks on media          0
# Time on Page (sec)       0
# user_id                  0
# dtype: int64

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
print(assessment_da25.dtypes)
# Out:
# Variant                   object
# Number of page views       int64
# GMV (in $)               float64
# Number of add to cart      int64
# Clicks on media            int64
# Time on Page (sec)         int64
# user_id                    int64
# dtype: object

# %%
print(assessment_da25.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Variant                2000 non-null   object
#  1   Number of page views   2000 non-null   int64
#  2   GMV (in $)             2000 non-null   float64
#  3   Number of add to cart  2000 non-null   int64
#  4   Clicks on media        2000 non-null   int64
#  5   Time on Page (sec)     2000 non-null   int64
#  6   user_id                2000 non-null   int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 109.5+ KB
# None

# %% [markdown]
# print("Business Problem: The company wants to improve the product page by deciding whether to implement a vertical media rail.")

# %%
print("Null Hypothesis (H0): There is no significant difference in key metrics between the horizontal and vertical media rails on the product page.")
print("Alternative Hypothesis (H1): There is a significant difference in key metrics between the horizontal and vertical media rails on the product page.")
# Out:
# Null Hypothesis (H0): There is no significant difference in key metrics between the horizontal and vertical media rails on the product page.
# Alternative Hypothesis (H1): There is a significant difference in key metrics between the horizontal and vertical media rails on the product page.

# %%
selected_metrics = ['Number of page views', 'GMV (in $)', 'Number of add to cart', 'Clicks on media']
primary_metric = 'GMV (in $)' 

print(f"Selected Metrics: {', '.join(selected_metrics)}")
print(f"Primary Metric: {primary_metric}")
# Out:
# Selected Metrics: Number of page views, GMV (in $), Number of add to cart, Clicks on media
# Primary Metric: GMV (in $)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu
import scipy.stats as stats

# %%
sns.set_palette("Set2")

selected_metrics = ['GMV (in $)', 'Clicks on media', 'Number of add to cart', 'Number of page views']

for metric in selected_metrics:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=metric, hue='Variant', kde=True, common_norm=False, element='step', stat='density', palette="Set2")
    
    plt.title(f'Distribution of {metric} between Variant A and Variant B')
    plt.show()

    variant_A_metric = df[df['Variant'] == 'A'][metric]
    variant_B_metric = df[df['Variant'] == 'B'][metric]
    
    statistic, p_value = mannwhitneyu(variant_A_metric, variant_B_metric, alternative='two-sided')

    sample_size_A = len(variant_A_metric)
    sample_size_B = len(variant_B_metric)

    mean_A = variant_A_metric.mean()
    mean_B = variant_B_metric.mean()

    alpha = 0.05
    print(f"\nMetric: {metric}")
    print(f"Sample Size for Variant A: {sample_size_A}")
    print(f"Sample Size for Variant B: {sample_size_B}")
    print(f"Mean for Variant A: {mean_A}")
    print(f"Mean for Variant B: {mean_B}")
    print(f"Mann-Whitney U Test Statistic: {statistic}")
    print(f"P-Value: {p_value}")

    if p_value < alpha:
        print("Reject the null hypothesis. There is a significant difference between the variants.")
    else:
        print("Fail to reject the null hypothesis. There is no significant difference between the variants.")
# Out:
# Metric: GMV (in $)
# Sample Size for Variant A: 1000
# Sample Size for Variant B: 1000
# Mean for Variant A: 7.689989999999999
# Mean for Variant B: 9.28953
# Mann-Whitney U Test Statistic: 491552.0
# P-Value: 0.18421295888108657
# Fail to reject the null hypothesis. There is no significant difference between the variants.
# Metric: Clicks on media
# Sample Size for Variant A: 1000
# Sample Size for Variant B: 1000
# Mean for Variant A: 1.495
# Mean for Variant B: 1.324
# Mann-Whitney U Test Statistic: 539787.5
# P-Value: 0.0013805009992892624
# Reject the null hypothesis. There is a significant difference between the variants.
# Metric: Number of add to cart
# Sample Size for Variant A: 1000
# Sample Size for Variant B: 1000
# Mean for Variant A: 1.884
# Mean for Variant B: 2.469
# Mann-Whitney U Test Statistic: 403630.0
# P-Value: 2.4339016227860634e-14
# Reject the null hypothesis. There is a significant difference between the variants.
# Metric: Number of page views
# ...
